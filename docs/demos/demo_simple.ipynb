# %% [markdown]
# # Simple Demo Example
# This is an example demo to test the gallery.b

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Create Random Data and Plot
# This is to test the plot viewing in the gallery.

# %%
data = np.random.rand(100)
print(data.shape)
# Out:
# (100,)

# %%
plt.plot(data)
